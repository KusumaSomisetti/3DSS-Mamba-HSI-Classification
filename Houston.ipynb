# %%
# Downgrade numpy to prevent incompatibility
# !pip install numpy==1.24.4

# Install PyTorch 2.0.1 + torchvision 0.15.2 with CUDA 11.8 (Colab GPU compatible)
# !pip install torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118

# Install dependencies
# !pip install scipy scikit-learn matplotlib fvcore ninja

# Clone model and install Mamba
# !git clone https://github.com/IIP-Team/3DSS-Mamba.git
# %cd 3DSS-Mamba
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 577.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 112.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 109.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89990 sha256=4c07e2f152dd058111f6a3d30d8048b858ef77335aadf2257d040955951e8188
#   Stored in directory: /root/.cache/pip/wheels/fc/5d/45/34fe9945d5e45e261134e72284395be36c2d4828af38e2b0fe
# Successfully built lit
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-185c1d4b-269a-42b0-81e6-0a11d5e9e28b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-185c1d4b-269a-42b0-81e6-0a11d5e9e28b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Make the target directory if it doesn't exist
os.makedirs('./data/Houston', exist_ok=True)

# %%
import shutil

# Move files into the structured path
shutil.move('./Houston13.mat', './data/Houston/Houston13.mat')
shutil.move('./Houston13_7gt.mat', './data/Houston/Houston13_7gt.mat')
# Out:
# './data/Houston/Houston13_7gt.mat'

# %%
import h5py

# %%
import h5py

with h5py.File('./data/Houston/Houston13.mat', 'r') as f:
    print("Keys in Houston13.mat:", list(f.keys()))
# Out:
# Keys in Houston13.mat: ['ori_data']

# %%
import h5py

with h5py.File('./data/Houston/Houston13_7gt.mat', 'r') as f:
    print("Keys in Houston13_7gt.mat:", list(f.keys()))
# Out:
# Keys in Houston13_7gt.mat: ['map']

# %%
# !python main_Mamba.py
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# WARNING: cannot import selective_scan_cuda_oflex.
# No module named 'selective_scan_cuda_oflex'
# WARNING: cannot import selective_scan_cuda_core.
# No module named 'selective_scan_cuda_core'
# WARNING: cannot import selective_scan_cuda.
# No module named 'selective_scan_cuda'
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Hyperspectral data shape:  (210, 954, 48)
# Label shape:  (210, 954)
#
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (210, 954, 30)
#
# ...

# %%
# !python main_Mamba.py
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# WARNING: cannot import selective_scan_cuda_oflex.
# No module named 'selective_scan_cuda_oflex'
# WARNING: cannot import selective_scan_cuda_core.
# No module named 'selective_scan_cuda_core'
# WARNING: cannot import selective_scan_cuda.
# No module named 'selective_scan_cuda'
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Hyperspectral data shape:  (210, 954, 48)
# Label shape:  (210, 954)
#
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (210, 954, 30)
#
# ...

# %%
# !python main_Mamba.py
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# WARNING: cannot import selective_scan_cuda_oflex.
# No module named 'selective_scan_cuda_oflex'
# WARNING: cannot import selective_scan_cuda_core.
# No module named 'selective_scan_cuda_core'
# WARNING: cannot import selective_scan_cuda.
# No module named 'selective_scan_cuda'
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Hyperspectral data shape:  (210, 954, 48)
# Label shape:  (210, 954)
#
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (210, 954, 30)
#
# ...

# %%
# !python main_Mamba.py
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# WARNING: cannot import selective_scan_cuda_oflex.
# No module named 'selective_scan_cuda_oflex'
# WARNING: cannot import selective_scan_cuda_core.
# No module named 'selective_scan_cuda_core'
# WARNING: cannot import selective_scan_cuda.
# No module named 'selective_scan_cuda'
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Hyperspectral data shape:  (210, 954, 48)
# Label shape:  (210, 954)
#
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (210, 954, 30)
#
# ...

# %%
# !python main_Mamba.py
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# WARNING: cannot import selective_scan_cuda_oflex.
# No module named 'selective_scan_cuda_oflex'
# WARNING: cannot import selective_scan_cuda_core.
# No module named 'selective_scan_cuda_core'
# WARNING: cannot import selective_scan_cuda.
# No module named 'selective_scan_cuda'
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Hyperspectral data shape:  (210, 954, 48)
# Label shape:  (210, 954)
#
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (210, 954, 30)
#
# ...
